# %%
import numpy as np
import pandas as pd
import itertools
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
import tensorflow as tf

# %%
#Read the data
df=pd.read_csv('news.csv')
#Get shape and head
df.shape
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
#DataFlair - Get the labels
labels=df.label
labels.head()
# Out:
# 0    FAKE
# 1    FAKE
# 2    REAL
# 3    FAKE
# 4    REAL
# Name: label, dtype: object

# %%
#DataFlair - Split the dataset
x_train,x_test,y_train,y_test=train_test_split(df['text'], labels, test_size=0.2, random_state=7)

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words=['english', 'the'], max_df=0.7)

#DataFlair - Fit and transform train set, transform test set
tfidf_train=tfidf_vectorizer.fit_transform(x_train) 
tfidf_test=tfidf_vectorizer.transform(x_test)

# %%
#DataFlair - Initialize a PassiveAggressiveClassifier
pac=PassiveAggressiveClassifier(max_iter=50)
pac.fit(tfidf_train,y_train)
#DataFlair - Predict on the test set and calculate accuracy
y_pred=pac.predict(tfidf_test)
score=accuracy_score(y_test,y_pred)
print(f'Accuracy: {round(score*100,2)}%')
# Out:
# Accuracy: 93.05%

# %%
#DataFlair - Build confusion matrix
confusion_matrix(y_test,y_pred, labels=['FAKE','REAL'])
# Out:
# array([[591,  47],
#        [ 41, 588]], dtype=int64)

# %% [markdown]
# ## Now lets use deep learning and see the differnece

# %%
## data preprocessing

# %%
df = pd.read_csv('news.csv')
df.head()
# Out:
#    Unnamed: 0                                              title  \
# 0        8476                       You Can Smell Hillary’s Fear
# 1       10294  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        3608        Kerry to go to Paris in gesture of sympathy
# 3       10142  Bernie supporters on Twitter erupt in anger ag...
# 4         875   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df.head()
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text label
# 0  Daniel Greenfield, a Shillman Journalism Fello...  FAKE
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...  FAKE
# 2  U.S. Secretary of State John F. Kerry said Mon...  REAL
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...  FAKE
# 4  It's primary day in New York and front-runners...  REAL

# %%
## title and text will be two inputs for our model and output will bw bibary 1 for fake and 0 for real

# %%
def label_to_binary(element):
    if element == 'FAKE':
        return 1
    else :
        return 0
    
df['label']  = df['label'].map(label_to_binary)

# %%
df.head()
# Out:
#                                                title  \
# 0                       You Can Smell Hillary’s Fear
# 1  Watch The Exact Moment Paul Ryan Committed Pol...
# 2        Kerry to go to Paris in gesture of sympathy
# 3  Bernie supporters on Twitter erupt in anger ag...
# 4   The Battle of New York: Why This Primary Matters
#
#                                                 text  label
# 0  Daniel Greenfield, a Shillman Journalism Fello...      1
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...      1
# 2  U.S. Secretary of State John F. Kerry said Mon...      0
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...      1
# 4  It's primary day in New York and front-runners...      0

# %%
X_train, X_test, y_train, y_test = train_test_split(df['title'] + ' ' + df['text'], df['label'], test_size = 0.2, random_state = 7)

# %%
## now we need to use two tokenizer to convert title and text so that we can feed it to our model
df['title'] + ' ' + df

# %%
# using keras tokenizer

tokenizer = tf.keras.preprocessing.text.Tokenizer()

tokenizer.fit_on_texts(X_train.values)


tokenizer_config  = tokenizer.get_config()

# %%
tokenizer_config.keys()
# Out:
# dict_keys(['num_words', 'filters', 'lower', 'split', 'char_level', 'oov_token', 'document_count', 'word_counts', 'word_docs', 'index_docs', 'index_word', 'word_index'])

# %%
import json
word_index = json.loads(tokenizer_config['word_index'])
index_word = json.loads(tokenizer_config['index_word'])

# %%
index_word
# Out:
# {'1': 'the',
#  '2': 'to',
#  '3': 'of',
#  '4': 'and',
#  '5': 'a',
#  '6': 'in',
#  '7': 'that',
#  '8': 'is',
#  '9': 'for',
#  '10': 'on',
#  '11': 'as',
#  '12': 'it',
#  '13': 'with',
#  '14': 'he',
#  '15': 'was',
#  '16': 'are',
#  '17': 'be',
#  '18': 'by',
#  '19': 'this',
#  '20': 'have',
#  '21': 'not',
#  '22': '”',
#  '23': 'his',
#  '24': 'has',
#  '25': 'at',
#  '26': 'said',
#  '27': 'but',
#  '28': 'from',
#  '29': 'trump',
#  '30': 'they',
#  '31': 'an',
#  '32': 'who',
#  '33': 'i',
#  '34': 'will',
#  '35': 'we',
#  '36': 'clinton',
#  '37': 'or',
#  '38': 'about',
#  '39': 'you',
#  '40': 'their',
#  '41': 'more',
#  '42': 'would',
#  '43': 'all',
#  '44': 'one',
#  '45': 'been',
#  '46': 'her',
#  '47': 'people',
#  '48': 'if',
#  '49': 'what',
#  '50': 'were',
#  '51': 'she',
#  '52': 'had',
#  '53': 'which',
#  '54': 'out',
#  '55': 'so',
#  '56': 'new',
#  '57': 'when',
#  '58': 'up',
#  '59': 'there',
#  '60': 'state',
#  '61': 'no',
#  '62': 'than',
#  '63': 'can',
#  '64': 'president',
#  '65': '—',
#  '66': 'our',
#  '67': 'also',
#  '68': 'us',
#  '69': 'other',
#  '70': 'campaign',
#  '71': 'after',
#  '72': 'over',
#  '73': 'do',
#  '74': 'some',
#  '75': 'just',
#  '76': 'like',
#  '77': 'its',
#  '78': 'time',
#  '79': 'hillary',
#  '80': 'them',
#  '81': 'into',
#  '82': 'obama',
#  '83': 'now',
#  '84': 'could',
#  '85': 'even',
#  '86': 'how',
#  '87': 'states',
#  '88': 'only',
#  '89': 'him',
#  '90': 'most',
#  '91': 'because',
#  '92': 'u',
#  '93': 's',
#  '94': 'many',
#  '95': 'republican',
#  '96': '–',
#  '97': 'two',
#  '98': 'election',
#  '99': 'first',
#  '100': 'those',
#  '101': 'these',
#  '102': 'american',
#  '103': 'against',
#  '104': 'political',
#  '105': 'any',
#  '106': 'party',
#  '107': 'government',
#  '108': 'years',
#  '109': 'get',
#  '110': 'year',
#  '111': 'house',
#  '112': 'going',
#  '113': 'while',
#  '114': 'your',
#  '115': 'world',
#  '116': 'presidential',
#  '117': 'being',
#  '118': 'where',
#  '119': 'last',
#  '120': 'make',
#  '121': 'before',
#  '122': 'donald',
#  '123': 'my',
#  '124': 'it’s',
#  '125': 'white',
#  '126': 'way',
#  '127': 'think',
#  '128': 'news',
#  '129': '2016',
#  '130': 'may',
#  '131': 'democratic',
#  '132': 'then',
#  '133': 'say',
#  '134': 'much',
#  '135': 'should',
#  '136': 'very',
#  '137': 'right',
#  '138': 'told',
#  '139': 'did',
#  '140': 'war',
#  '141': 'back',
#  '142': 'percent',
#  '143': 'well',
#  '144': 'country',
#  '145': 'know',
#  '146': 'voters',
#  '147': 'sanders',
#  '148': 'united',
#  '149': 'national',
#  '150': 'made',
#  '151': 'such',
#  '152': 'republicans',
#  '153': 'day',
#  '154': 'support',
#  '155': 'former',
#  '156': 'media',
#  '157': 'see',
#  '158': 'down',
#  '159': 'take',
#  '160': 'both',
#  '161': 'vote',
#  '162': 'still',
#  '163': 'police',
#  '164': 'during',
#  '165': 'same',
#  '166': 'says',
#  '167': 'since',
#  '168': 'public',
#  '169': 'law',
#  '170': 'candidate',
#  '171': 'between',
#  '172': 'through',
#  '173': 'here',
#  '174': 'want',
#  '175': 'policy',
#  '176': 'me',
#  '177': 'another',
#  '178': 'according',
#  '179': 'own',
#  '180': 'americans',
#  '181': 'off',
#  '182': 'why',
#  '183': 'america',
#  '184': 'bush',
#  '185': 'cruz',
#  '186': 'go',
#  '187': 'long',
#  '188': 'don’t',
#  '189': 'gop',
#  '190': 'part',
#  '191': 'under',
#  '192': 'called',
#  '193': 'security',
#  '194': 'debate',
#  '195': 'washington',
#  '196': 'democrats',
#  '197': 'military',
#  '198': 'every',
#  '199': '1',
#  '200': 'russia',
#  '201': 'work',
#  '202': 'never',
#  '203': 'good',
#  '204': 'week',
#  '205': 'including',
#  '206': 'bill',
#  '207': 'need',
#  '208': 'does',
#  '209': 'use',
#  '210': 'change',
#  '211': "it's",
#  '212': 'congress',
#  '213': 'too',
#  '214': '000',
#  '215': 'black',
#  '216': 'power',
#  '217': 'far',
#  '218': 'trump’s',
#  '219': 'foreign',
#  '220': 'whether',
#  '221': 'among',
#  '222': 'next',
#  '223': 'fact',
#  '224': 'race',
#  '225': 'three',
#  '226': 'candidates',
#  '227': 'system',
#  '228': 'around',
#  '229': 'fbi',
#  '230': 'federal',
#  '231': 'come',
#  '232': 'women',
#  '233': 'might',
#  '234': 'times',
#  '235': 'money',
#  '236': 'department',
#  '237': 'point',
#  '238': 'really',
#  '239': 'court',
#  '240': 'win',
#  '241': '“the',
#  '242': 'case',
#  '243': 'left',
#  '244': 'things',
#  '245': 'end',
#  '246': 'life',
#  '247': 'deal',
#  '248': 'officials',
#  '249': 'group',
#  '250': 'secretary',
#  '251': 'york',
#  '252': 'saying',
#  '253': 'john',
#  '254': 'already',
#  '255': 'general',
#  '256': 'million',
#  '257': 'senate',
#  '258': 'likely',
#  '259': 'used',
#  '260': 'big',
#  '261': 'without',
#  '262': 'believe',
#  '263': 'email',
#  '264': 'health',
#  '265': 'something',
#  '266': 'man',
#  '267': 'days',
#  '268': 'put',
#  '269': 'help',
#  '270': 'emails',
#  '271': 'syria',
#  '272': 'report',
#  '273': 'russian',
#  '274': 'primary',
#  '275': 'iran',
#  '276': '10',
#  '277': 'office',
#  '278': 'again',
#  '279': 'recent',
#  '280': 'found',
#  '281': 'top',
#  '282': 'though',
#  '283': 'information',
#  '284': 'least',
#  '285': 'however',
#  '286': 'yet',
#  '287': '“i',
#  '288': 'past',
#  '289': 'post',
#  '290': 'better',
#  '291': 'less',
#  '292': 'rubio',
#  '293': 'high',
#  '294': 'issue',
#  '295': 'real',
#  '296': 'few',
#  '297': 'clinton’s',
#  '298': '2',
#  '299': 'look',
#  '300': 'administration',
#  '301': 'place',
#  '302': 'attack',
#  '303': 'nominee',
#  '304': 'press',
#  '305': 'show',
#  '306': 'today',
#  '307': 'tuesday',
#  '308': 'run',
#  '309': 'got',
#  '310': 'become',
#  '311': 'rights',
#  '312': 'supporters',
#  '313': 'great',
#  '314': 'nuclear',
#  '315': 'night',
#  '316': 'must',
#  '317': 'clear',
#  '318': 'old',
#  '319': 'politics',
#  '320': 'control',
#  '321': 'asked',
#  '322': 'that’s',
#  '323': 'isis',
#  '324': 'issues',
#  '325': 'early',
#  '326': 'october',
#  '327': 'each',
#  '328': 'little',
#  '329': 'sen',
#  '330': 'four',
#  '331': 'came',
#  '332': 'away',
#  '333': 'lot',
#  '334': 'free',
#  '335': 'history',
#  '336': 'attacks',
#  '337': 'justice',
#  '338': 'home',
#  '339': 'important',
#  '340': 'actually',
#  '341': 'conservative',
#  '342': 'november',
#  '343': 'question',
#  '344': 'once',
#  '345': 'ever',
#  '346': 'economic',
#  '347': 'best',
#  '348': 'number',
#  '349': 'city',
#  '350': 'social',
#  '351': 'speech',
#  '352': '3',
#  '353': 'several',
#  '354': 'major',
#  '355': 'family',
#  '356': 'keep',
#  '357': 'force',
#  '358': '5',
#  '359': 'investigation',
#  '360': 'members',
#  '361': 'working',
#  '362': 'making',
#  '363': 'enough',
#  '364': 'months',
#  '365': 'leaders',
#  '366': 'different',
#  '367': 'thing',
#  '368': 'com',
#  '369': 'took',
#  '370': 'anti',
#  '371': 'voting',
#  '372': 'others',
#  '373': 'video',
#  '374': 'fox',
#  '375': 'doing',
#  '376': 'act',
#  '377': 'second',
#  '378': 'later',
#  '379': 'business',
#  '380': 'given',
#  '381': 'ago',
#  '382': 'until',
#  '383': 'based',
#  '384': 'process',
#  '385': 'order',
#  '386': 'give',
#  '387': 'committee',
#  '388': 'polls',
#  '389': 'seen',
#  '390': 'tax',
#  '391': '11',
#  '392': 'call',
#  '393': 'children',
#  '394': 'behind',
#  '395': 'florida',
#  '396': 'statement',
#  '397': 'plan',
#  '398': 'iraq',
#  '399': 'course',
#  '400': 'care',
#  '401': 'iowa',
#  '402': 'paul',
#  '403': 'running',
#  '404': 'south',
#  '405': 'reported',
#  '406': 'majority',
#  '407': 'nothing',
#  '408': 'private',
#  '409': 'countries',
#  '410': 'find',
#  '411': 'forces',
#  '412': 'international',
#  '413': 'across',
#  '414': 'trying',
#  '415': 'official',
#  '416': 'lead',
#  '417': 'matter',
#  '418': 'middle',
#  '419': 'decision',
#  '420': 'evidence',
#  '421': 'thursday',
#  '422': 'done',
#  '423': 'set',
#  '424': 'nomination',
#  '425': '2012',
#  '426': 'person',
#  '427': 'university',
#  '428': 'hard',
#  '429': 'instead',
#  '430': 'possible',
#  '431': 'convention',
#  '432': "don't",
#  '433': 'problem',
#  '434': 'he’s',
#  '435': 'wednesday',
#  '436': 'human',
#  '437': 'global',
#  '438': 'fight',
#  '439': 'cnn',
#  '440': 'always',
#  '441': 'having',
#  '442': '4',
#  '443': 'continue',
#  '444': 'means',
#  '445': 'story',
#  '446': 'director',
#  '447': 'islamic',
#  '448': 'wall',
#  '449': 'month',
#  '450': 'close',
#  '451': 'mr',
#  '452': 'al',
#  '453': 'establishment',
#  '454': 'friday',
#  '455': 'monday',
#  '456': 'groups',
#  '457': 'poll',
#  '458': 'am',
#  '459': 'known',
#  '460': 'immigration',
#  '461': 'often',
#  '462': 'within',
#  '463': 'delegates',
#  '464': 'north',
#  '465': 'added',
#  '466': 'himself',
#  '467': 'stop',
#  '468': 'nation',
#  '469': 'taking',
#  '470': 'source',
#  '471': 'able',
#  '472': 'job',
#  '473': 'almost',
#  '474': 'men',
#  '475': 'program',
#  '476': 'wrote',
#  '477': 'future',
#  '478': 'face',
#  '479': 'r',
#  '480': 'comes',
#  '481': 'anything',
#  '482': 'front',
#  '483': 'earlier',
#  '484': 'reason',
#  '485': "trump's",
#  '486': 'led',
#  '487': 'kind',
#  '488': 'interview',
#  '489': 'name',
#  '490': 'economy',
#  '491': 'line',
#  '492': 'won',
#  '493': 'class',
#  '494': 'center',
#  '495': 'votes',
#  '496': 'went',
#  '497': 'bernie',
#  '498': 'trade',
#  '499': 'pay',
#  '500': 'five',
#  '501': 'defense',
#  '502': 'senator',
#  '503': 'along',
#  '504': 'rather',
#  '505': 'questions',
#  '506': 'leader',
#  '507': 'share',
#  '508': 'sure',
#  '509': 'side',
#  '510': 'killed',
#  '511': 'personal',
#  '512': 'doesn’t',
#  '513': 'using',
#  '514': 'foundation',
#  '515': 'reports',
#  '516': 'large',
#  '517': 'didn’t',
#  '518': 'move',
#  '519': 'small',
#  '520': 'community',
#  '521': 'street',
#  '522': 'full',
#  '523': 'getting',
#  '524': 'israel',
#  '525': 'coming',
#  '526': '9',
#  '527': '“we',
#  '528': 'talk',
#  '529': 'either',
#  '530': 'true',
#  '531': 'third',
#  '532': 'idea',
#  '533': 'someone',
#  '534': 'young',
#  '535': 'twitter',
#  '536': 'chief',
#  '537': 'water',
#  '538': 'elections',
#  '539': 'taken',
#  '540': 'points',
#  '541': '2015',
#  '542': 'together',
#  '543': 'strong',
#  '544': 'key',
#  '545': 'data',
#  '546': 'action',
#  '547': '20',
#  '548': '…',
#  '549': 'facebook',
#  '550': 'woman',
#  '551': 'violence',
#  '552': 'nearly',
#  '553': 'financial',
#  '554': 'let',
#  '555': 'victory',
#  '556': 'd',
#  '557': 'school',
#  '558': 'comments',
#  '559': 'start',
#  '560': 'level',
#  '561': 'released',
#  '562': 'lives',
#  '563': 'held',
#  '564': 'air',
#  '565': 'term',
#  '566': 'needs',
#  '567': 'late',
#  '568': 'george',
#  '569': 'bad',
#  '570': 'despite',
#  '571': 'open',
#  '572': 'makes',
#  '573': 'team',
#  '574': 'texas',
#  '575': 'simply',
#  '576': 'death',
#  '577': '\xa0',
#  '578': 'local',
#  '579': 'sunday',
#  '580': 'following',
#  '581': 'gun',
#  '582': 'weeks',
#  '583': 'gov',
#  '584': "that's",
#  '585': 'i’m',
#  '586': '30',
#  '587': 'themselves',
#  '588': 'seems',
#  '589': 'potential',
#  '590': '15',
#  '591': 'supreme',
#  '592': 'further',
#  '593': 'words',
#  '594': 'probably',
#  '595': 'looking',
#  '596': 'there’s',
#  '597': 'governor',
#  '598': 'hampshire',
#  '599': 'lost',
#  '600': 'feel',
#  '601': 'tell',
#  '602': 'thought',
#  '603': 'example',
#  '604': 'china',
#  '605': "he's",
#  '606': '2014',
#  '607': 'anyone',
#  '608': 'current',
#  '609': 'hope',
#  '610': 'began',
#  '611': '6',
#  '612': '8',
#  '613': 'intelligence',
#  '614': 'outside',
#  '615': 'article',
#  '616': 'can’t',
#  '617': 'role',
#  '618': '2008',
#  '619': 'head',
#  '620': 'e',
#  '621': '7',
#  '622': 'millions',
#  '623': 'live',
#  '624': 'legal',
#  '625': 'non',
#  '626': 'march',
#  '627': 'barack',
#  '628': 'turn',
#  '629': 'talking',
#  '630': 'half',
#  '631': 'recently',
#  '632': 'mean',
#  '633': 'wants',
#  '634': 'record',
#  '635': 'position',
#  '636': 'east',
#  '637': 'cannot',
#  '638': 'message',
#  '639': 'syrian',
#  '640': 'read',
#  '641': 'especially',
#  '642': 'everything',
#  '643': 'elected',
#  '644': 'executive',
#  '645': 'policies',
#  '646': 'effort',
#  '647': 'event',
#  '648': 'rules',
#  '649': 'research',
#  '650': 'everyone',
#  '651': 'service',
#  '652': 'threat',
#  '653': 'freedom',
#  '654': 'officers',
#  '655': 'meeting',
#  '656': 'announced',
#  '657': 'toward',
#  '658': 'ground',
#  '659': 'civil',
#  '660': 'weapons',
#  '661': 'list',
#  '662': 'results',
#  '663': 'minister',
#  '664': 'moment',
#  '665': 'view',
#  '666': 'presidency',
#  '667': 'entire',
#  '668': 'result',
#  '669': 'college',
#  '670': 'self',
#  '671': 'plans',
#  '672': 'shows',
#  '673': 'whose',
#  '674': 'itself',
#  '675': 'interest',
#  '676': 'try',
#  '677': 'hand',
#  '678': 'whole',
#  '679': 'sense',
#  '680': 'comment',
#  '681': 'parties',
#  '682': 'ted',
#  '683': 'agreement',
#  '684': 'response',
#  '685': 'energy',
#  '686': 'jobs',
#  '687': 'western',
#  '688': 'obama’s',
#  '689': "clinton's",
#  '690': 'hours',
#  '691': 'common',
#  '692': '“',
#  '693': 'thousands',
#  '694': 'reality',
#  '695': 'perhaps',
#  '696': 'sent',
#  '697': 'access',
#  '698': 'west',
#  '699': 'understand',
#  '700': 'leave',
#  '701': 'near',
#  '702': 'carolina',
#  '703': 'marriage',
#  '704': 'senior',
#  '705': 'watch',
#  '706': 'six',
#  '707': 'claim',
#  '708': 'movement',
#  '709': 'love',
#  '710': 'ryan',
#  '711': 'hold',
#  '712': 'comey',
#  '713': 'climate',
#  '714': 'oil',
#  '715': 'vice',
#  '716': 'ohio',
#  '717': 'rally',
#  '718': 'happened',
#  '719': 'decades',
#  '720': 'truth',
#  '721': 'putin',
#  '722': '0',
#  '723': '12',
#  '724': 'morning',
#  '725': 'problems',
#  '726': 'liberal',
#  '727': 'stand',
#  '728': 'started',
#  '729': 'they’re',
#  '730': 'single',
#  '731': 'wrong',
#  '732': 'area',
#  '733': 'crisis',
#  '734': 'billion',
#  '735': 'religious',
#  '736': 'although',
#  '737': '50',
#  '738': 'numbers',
#  '739': 'turned',
#  '740': 'play',
#  '741': '’',
#  '742': 'voter',
#  '743': 'romney',
#  '744': 'bring',
#  '745': 'isn’t',
#  '746': 'serious',
#  '747': 'jeb',
#  '748': 'conservatives',
#  '749': 'became',
#  '750': 'similar',
#  '751': 'stage',
#  '752': 'terrorism',
#  '753': 'market',
#  '754': 'citizens',
#  '755': 'kasich',
#  '756': 'wanted',
#  '757': 'efforts',
#  '758': 'expected',
#  '759': 'workers',
#  '760': 'saudi',
#  '761': 'field',
#  '762': 'book',
#  '763': 'latest',
#  '764': 'follow',
#  '765': 'europe',
#  '766': '100',
#  '767': 'choice',
#  '768': 'california',
#  '769': 'sign',
#  '770': 'congressional',
#  '771': 'chance',
#  '772': 'sex',
#  '773': 'enforcement',
#  '774': 'short',
#  '775': 'gave',
#  '776': 'focus',
#  '777': 'population',
#  '778': 'final',
#  '779': 'address',
#  '780': 'saturday',
#  '781': 'tried',
#  '782': 'strategy',
#  '783': 'david',
#  '784': 'attention',
#  '785': 'conference',
#  '786': 'failed',
#  '787': 'secret',
#  '788': 'terrorist',
#  '789': 'member',
#  '790': 'ahead',
#  '791': 'longer',
#  '792': 'immigrants',
#  '793': 'mind',
#  '794': 'w',
#  '795': 'leading',
#  '796': 'union',
#  '797': 'laws',
#  '798': 'actions',
#  '799': 'gold',
#  '800': 'ways',
#  '801': 'reporters',
#  '802': 'mass',
#  '803': 'happen',
#  '804': 'received',
#  '805': 'winning',
#  '806': 'society',
#  '807': 'criminal',
#  '808': 'c',
#  '809': 'published',
#  '810': 'food',
#  '811': '25',
#  '812': 'agency',
#  '813': 'claims',
#  '814': 'fear',
#  '815': 'experience',
#  '816': 'paris',
#  '817': 'low',
#  '818': 'beyond',
#  '819': 'chairman',
#  '820': 'budget',
#  '821': 'study',
#  '822': 'nations',
#  '823': 'calls',
#  '824': 'illegal',
#  '825': 'we’re',
#  '826': 'calling',
#  '827': 'special',
#  '828': 'land',
#  '829': 'involved',
#  '830': 'forward',
#  '831': 'm',
#  '832': 'speaking',
#  '833': 'shot',
#  '834': 'spent',
#  '835': 'answer',
#  '836': 'speaker',
#  '837': 'standing',
#  '838': 'base',
#  '839': "didn't",
#  '840': 'else',
#  '841': 'fighting',
#  '842': 'worked',
#  '843': '2013',
#  '844': 'crime',
#  '845': 'cause',
#  '846': 'risk',
#  '847': 'particularly',
#  '848': 'obamacare',
#  '849': 'leadership',
#  '850': 'staff',
#  '851': 'needed',
#  '852': 'democrat',
#  '853': 'server',
#  '854': "i'm",
#  '855': 'army',
#  '856': 'christie',
#  '857': 'cases',
#  '858': 'muslim',
#  '859': 'allow',
#  '860': 'soon',
#  '861': 'increase',
#  '862': 'events',
#  '863': 'border',
#  '864': 'goes',
#  '865': 'johnson',
#  '866': 'spending',
#  '867': 'daily',
#  '868': "obama's",
#  '869': 'situation',
#  '870': 'wikileaks',
#  '871': 'rest',
#  '872': 'showed',
#  '873': 'company',
#  '874': 'companies',
#  '875': 'authorities',
#  '876': 'paid',
#  '877': 'pro',
#  '878': 'saw',
#  '879': 'protect',
#  '880': 'account',
#  '881': 'central',
#  '882': 'reform',
#  '883': 'debt',
#  '884': 'difficult',
#  '885': 'allies',
#  '886': 'shooting',
#  '887': 'create',
#  '888': 'cost',
#  '889': 'interests',
#  '890': 'education',
#  '891': 'biden',
#  '892': 'fire',
#  '893': 'influence',
#  '894': 'related',
#  '895': 'hit',
#  '896': 'ask',
#  '897': 'build',
#  '898': 'letter',
#  '899': 'attorney',
#  '900': 'body',
#  '901': 'building',
#  '902': 'relations',
#  '903': 'friends',
#  '904': 'certainly',
#  '905': 'release',
#  '906': 'african',
#  '907': 'quite',
#  '908': 'rise',
#  '909': 'peace',
#  '910': 'rate',
#  '911': 'yes',
#  '912': 'higher',
#  '913': 'organization',
#  '914': 'muslims',
#  '915': 'bank',
#  '916': 'form',
#  '917': 'heard',
#  '918': 'significant',
#  '919': 'living',
#  '920': 'continued',
#  '921': 'provide',
#  '922': 'gets',
#  '923': 'seem',
#  '924': 'co',
#  '925': 'created',
#  '926': 'politicians',
#  '927': 'brought',
#  '928': 'associated',
#  '929': 'cut',
#  '930': 'due',
#  '931': 'super',
#  '932': 'dead',
#  '933': 'families',
#  '934': 'certain',
#  '935': 'james',
#  '936': 'terrorists',
#  '937': 'finally',
#  '938': 'consider',
#  '939': 'described',
#  '940': 'battle',
#  '941': 'knows',
#  '942': 'takes',
#  '943': 'n',
#  '944': 'network',
#  '945': 'you’re',
#  '946': 'income',
#  '947': 'game',
#  '948': 'planned',
#  '949': 'step',
#  '950': 'remains',
#  '951': 'european',
#  '952': 'biggest',
#  '953': 'july',
#  '954': 'noted',
#  '955': 'decided',
#  '956': 'mainstream',
#  '957': 'sources',
#  '958': 'students',
#  '959': 'june',
#  '960': 'county',
#  '961': 'electoral',
#  '962': 'industry',
#  '963': 'corporate',
#  '964': 'wife',
#  '965': 'independent',
#  '966': 'indeed',
#  '967': "doesn't",
#  '968': 'helped',
#  '969': 'quickly',
#  '970': 'born',
#  '971': 'opportunity',
#  '972': "there's",
#  '973': 'god',
#  '974': 'inside',
#  '975': 'terms',
#  '976': 'powerful',
#  '977': 'rep',
#  '978': 'claimed',
#  '979': 'opposition',
#  '980': 'dollars',
#  '981': 'church',
#  '982': 'french',
#  '983': 'appears',
#  '984': 'above',
#  '985': 'speak',
#  '986': 'views',
#  '987': 'democracy',
#  '988': '40',
#  '989': 'worse',
#  '990': 'word',
#  '991': "we're",
#  '992': 'lose',
#  '993': 'terror',
#  '994': 'challenge',
#  '995': 'growing',
#  '996': 'ready',
#  '997': 'tv',
#  '998': 'upon',
#  '999': 'passed',
#  '1000': 'maybe',
#  ...}

# %%
## now lets convert texts into sequences

X_train_seq = tokenizer.texts_to_sequences(X_train.values)


X_test_seq = tokenizer.texts_to_sequences(X_test.values)

# %%
## now lets pad the sequences

# %%
X_train_seq_padded = tf.keras.preprocessing.sequence.pad_sequences(X_train_seq, maxlen = 500)

X_test_seq_padded = tf.keras.preprocessing.sequence.pad_sequences(X_test_seq, maxlen = 500)

# %%
input_dim_emb= len(word_index)+1
input_dim_emb
# Out:
# 88927

# %%
## now we are ready to create our model

# %%
def get_model(input_dim_emb):
    
    
    inputs = tf.keras.layers.Input(shape = (None, ))

    x = tf.keras.layers.Embedding(input_dim_emb, output_dim=10, mask_zero=True)(inputs)
    x = tf.keras.layers.Masking()(x)
    x = tf.keras.layers.Dropout(0.4)(x)

    x = tf.keras.layers.LSTM(32, return_sequences=True)(x)
    x = tf.keras.layers.Dropout(0.4)(x)

    x = tf.keras.layers.LSTM(16)(x)
    x = tf.keras.layers.Dropout(0.4)(x)

    x = tf.keras.layers.Dense(16, activation = 'relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)
    x = tf.keras.layers.Dense(8, activation = 'relu')(x)
    x = tf.keras.layers.Dropout(0.4)(x)

    outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    
    model = tf.keras.models.Model(inputs  =  inputs, outputs = outputs)
    model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return model

# %%
model = get_model(input_dim_emb)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        (None, None, 10)          889270
# _________________________________________________________________
# masking (Masking)            (None, None, 10)          0
# _________________________________________________________________
# dropout (Dropout)            (None, None, 10)          0
# _________________________________________________________________
# lstm (LSTM)                  (None, None, 32)          5504
# _________________________________________________________________
# dropout_1 (Dropout)          (None, None, 32)          0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 16)                3136
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense (Dense)                (None, 16)                272
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 8)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 898,327
# Trainable params: 898,327
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X_train_seq_padded, y_train.values , epochs = 10, batch_size = 32, validation_data = (X_test_seq_padded, y_test.values))
# Out:
# Epoch 1/10
# 159/159 [==============================] - 16s 61ms/step - loss: 0.6930 - accuracy: 0.4957 - val_loss: 0.6871 - val_accuracy: 0.5746
# Epoch 2/10
# 159/159 [==============================] - 7s 46ms/step - loss: 0.6212 - accuracy: 0.6763 - val_loss: 0.4383 - val_accuracy: 0.8335
# Epoch 3/10
# 159/159 [==============================] - 7s 45ms/step - loss: 0.4200 - accuracy: 0.8730 - val_loss: 0.4341 - val_accuracy: 0.7964
# Epoch 4/10
# 159/159 [==============================] - 7s 46ms/step - loss: 0.2662 - accuracy: 0.9374 - val_loss: 0.3970 - val_accuracy: 0.8966
# Epoch 5/10
# 159/159 [==============================] - 8s 50ms/step - loss: 0.1689 - accuracy: 0.9648 - val_loss: 0.4623 - val_accuracy: 0.8769
# Epoch 6/10
# 159/159 [==============================] - 8s 48ms/step - loss: 0.0958 - accuracy: 0.9795 - val_loss: 0.4028 - val_accuracy: 0.8729
# Epoch 7/10
# 159/159 [==============================] - 8s 47ms/step - loss: 0.0835 - accuracy: 0.9818 - val_loss: 0.5478 - val_accuracy: 0.8895
# Epoch 8/10
# 159/159 [==============================] - 7s 47ms/step - loss: 0.0682 - accuracy: 0.9867 - val_loss: 0.6101 - val_accuracy: 0.8650
# Epoch 9/10
# 159/159 [==============================] - 7s 46ms/step - loss: 0.0446 - accuracy: 0.9900 - val_loss: 0.6617 - val_accuracy: 0.8808
# Epoch 10/10
# 159/159 [==============================] - 7s 47ms/step - loss: 0.0418 - accuracy: 0.9916 - val_loss: 0.6639 - val_accuracy: 0.8808

# %%
y_pred = model.predict(X_test_seq_padded)

# %%
y_pred = np.round(y_pred)

# %%
print(confusion_matrix(y_test.values, y_pred))
# Out:
# [[551  78]
#  [ 73 565]]

# %%
x_val = tokenizer.texts_to_sequences(['''India was downgraded to "partly free" for the first time since 1997 in an annual ranking of democracies by the U.S.-government funded research group Freedom House, which cited worsening civil rights under Prime Minister Narendra Modi.

The world's largest democracy slipped in rankings this year because of continuing discrimination against its Muslim citizens and increased harassment of government critics and journalists, according to the "Freedom in the World' report released by the Washington-based organization.

The report cited "a multi-year pattern in which the Hindu nationalist government and its allies have presided over rising violence and discriminatory policies." It listed several events in 2020 like religious riots in Delhi, use of sedition laws against critics and hardships endured by migrant workers after PM Modi announced a sudden lockdown to control the coronavirus pandemic.

India was among 73 nations downgraded for declines in political rights and civil liberties, affecting three-fourths of the world's population. The report, which ranks 210 nations, found that states designated "Not Free" have reached the highest since 2006. Those affected included not just authoritarian states like China, Belarus, and Venezuela, but also troubled democracies like the U.S. and India.

India's status change means that less than 20% of the world's people now live in a "free" country -- the smallest proportion since 1995, the report said. The changes in India since PM Modi took charge in 2014 "form part of a broader shift in the international balance between democracy and authoritarianism, with authoritarians generally enjoying impunity for their abuses and seizing new opportunities to consolidate power or crush dissent," the report said.'''])

# %%
x_val
# Out:
# [[1500,
#   15,
#   34344,
#   2,
#   4744,
#   334,
#   9,
#   1,
#   99,
#   78,
#   167,
#   4471,
#   6,
#   31,
#   2195,
#   3454,
#   3,
#   8320,
#   18,
#   1,
#   92,
#   93,
#   107,
#   2519,
#   649,
#   249,
#   653,
#   111,
#   53,
#   2045,
#   12543,
#   659,
#   311,
#   191,
#   1022,
#   663,
#   10732,
#   7874,
#   1,
#   4366,
#   1311,
#   987,
#   7187,
#   6,
#   12410,
#   19,
#   110,
#   91,
#   3,
#   2582,
#   2493,
#   103,
#   77,
#   858,
#   754,
#   4,
#   1306,
#   5844,
#   3,
#   107,
#   1472,
#   4,
#   1618,
#   178,
#   2,
#   1,
#   653,
#   6,
#   1,
#   272,
#   561,
#   18,
#   1,
#   195,
#   383,
#   913,
#   1,
#   272,
#   2045,
#   5,
#   4006,
#   110,
#   3168,
#   6,
#   53,
#   1,
#   5152,
#   5238,
#   107,
#   4,
#   77,
#   885,
#   20,
#   9858,
#   72,
#   1668,
#   551,
#   4,
#   13892,
#   645,
#   12,
#   3861,
#   353,
#   862,
#   6,
#   4624,
#   76,
#   735,
#   4308,
#   6,
#   9449,
#   209,
#   3,
#   25127,
#   797,
#   103,
#   1472,
#   4,
#   17833,
#   7794,
#   18,
#   4810,
#   759,
#   71,
#   2830,
#   7874,
#   656,
#   5,
#   4746,
#   37240,
#   2,
#   320,
#   1,
#   10363,
#   1500,
#   15,
#   221,
#   5764,
#   822,
#   34344,
#   9,
#   9790,
#   6,
#   104,
#   311,
#   4,
#   659,
#   4168,
#   6294,
#   225,
#   33084,
#   3,
#   1,
#   4366,
#   777,
#   1,
#   272,
#   53,
#   4224,
#   25680,
#   822,
#   280,
#   7,
#   87,
#   6488,
#   21,
#   334,
#   20,
#   1262,
#   1,
#   1414,
#   167,
#   2368,
#   100,
#   3450,
#   1107,
#   21,
#   75,
#   5487,
#   87,
#   76,
#   604,
#   14118,
#   4,
#   5201,
#   27,
#   67,
#   6066,
#   8320,
#   76,
#   1,
#   92,
#   93,
#   4,
#   1500,
#   29052,
#   1211,
#   210,
#   444,
#   7,
#   291,
#   62,
#   547,
#   3,
#   1,
#   4366,
#   47,
#   83,
#   623,
#   6,
#   5,
#   334,
#   144,
#   1,
#   9565,
#   6933,
#   167,
#   5894,
#   1,
#   272,
#   26,
#   1,
#   1084,
#   6,
#   1500,
#   167,
#   2830,
#   7874,
#   369,
#   1434,
#   6,
#   606,
#   916,
#   190,
#   3,
#   5,
#   2697,
#   1678,
#   6,
#   1,
#   412,
#   1818,
#   171,
#   987,
#   4,
#   10634,
#   13,
#   28430,
#   1927,
#   8052,
#   8297,
#   9,
#   40,
#   5070,
#   4,
#   10952,
#   56,
#   2515,
#   2,
#   9683,
#   216,
#   37,
#   7131,
#   5361,
#   1,
#   272,
#   26]]

# %%
x_val = tf.keras.preprocessing.sequence.pad_sequences(x_val, maxlen=500)

# %%
model.predict(x_val)
# Out:
# array([[3.964668e-05]], dtype=float32)
